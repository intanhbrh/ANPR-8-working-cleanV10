# %%
from ultralytics import YOLO

# %%
import os

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 4090'

# %% [markdown]
# ## Testing training params on a small model

# %%
#Smallest model
model = YOLO('yolov8x.pt')

# %%
# Training model
# Use this method instead of using the `os` library
results = model.train(data=r'C:\Users\user\Desktop\ANPR-8\ANPRmodel\train\datasets\data.yaml', epochs=10, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.0.232 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.222 🚀 Python-3.11.5 torch-2.1.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4090, 23028MiB)
# ...

# %%
#Exporting model

# %%
model = YOLO(os.path.join('runs', 'detect', 'train34', 'weights', 'best.pt'))

# %%
model.export(format='onnx')
# Out:
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.13 torch-2.1.0+cu121 CPU (13th Gen Intel Core(TM) i7-13700)
# Model summary (fused): 268 layers, 43608150 parameters, 0 gradients, 164.8 GFLOPs
#
# PyTorch: starting from 'runs/detect/train34/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (83.6 MB)
#
# ONNX: starting export with onnx 1.15.0 opset 17...
# ONNX: export success ✅ 1.2s, saved as 'runs/detect/train34/weights/best.onnx' (166.6 MB)
#
# Export complete (3.0s)
# Results saved to /home/aakash/Desktop/Programming/ANPR/YOLOv8/runs/detect/train34/weights
# Predict:         yolo predict task=detect model=runs/detect/train34/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs/detect/train34/weights/best.onnx imgsz=640 data=datasets/data.yaml
# Visualize:       https://netron.app
# 'runs/detect/train34/weights/best.onnx'

# %% [markdown]
# ## Training full scale model

# %%
model = YOLO('yolov8x.pt')

# %%
results = model.train(data=r'C:\Users\user\Desktop\ANPR-8\ANPRmodel\train\datasets\data.yaml', epochs=1000, imgsz=640, device = 0, save = True, save_period = 50, patience = 500)
# Out:
# New https://pypi.org/project/ultralytics/8.0.234 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.222 🚀 Python-3.11.5 torch-2.1.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4090, 23028MiB)
# ...

# %%
model = YOLO(os.path.join('runs', 'detect', 'train34', 'weights', 'best.pt'))

# %%
model.export(format='onnx')
# Out:
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.13 torch-2.1.0+cu121 CPU (13th Gen Intel Core(TM) i7-13700)
# Model summary (fused): 268 layers, 43608150 parameters, 0 gradients, 164.8 GFLOPs
#
# PyTorch: starting from 'runs/detect/train34/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (83.6 MB)
#
# ONNX: starting export with onnx 1.15.0 opset 17...
# ONNX: export success ✅ 1.2s, saved as 'runs/detect/train34/weights/best.onnx' (166.6 MB)
#
# Export complete (3.0s)
# Results saved to /home/aakash/Desktop/Programming/ANPR/YOLOv8/runs/detect/train34/weights
# Predict:         yolo predict task=detect model=runs/detect/train34/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs/detect/train34/weights/best.onnx imgsz=640 data=datasets/data.yaml
# Visualize:       https://netron.app
# 'runs/detect/train34/weights/best.onnx'
